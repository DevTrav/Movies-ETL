# %%
# Import Dependencies
import json
import pandas as pd
import numpy as np
import os
import re

# %%
# Save JSON file path
file_dir = '/Users/traverslaville/Desktop/Classwork/Movies-ETL/Resources/'
f'{file_dir}filename'
# Out:
# '/Users/traverslaville/Desktop/Classwork/Movies-ETL/Resources/filename'

# %%
# Load JSON file into a list of dictionaires
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

len(wiki_movies_raw)
# Out:
# 7311

# %%
# Invetigating JSON data

wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
# Create movies and ratings dataframes with kaggle data
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
# Review of dataframe content
#kaggle_metadata.head()
#ratings.head()
kaggle_metadata.sample(5)
# Out:
#        adult belongs_to_collection    budget  \
# 1660   False                   NaN  15000000
# 6034   False                   NaN   3500000
# 21046  False                   NaN         0
# 16296  False                   NaN         0
# 30849  False                   NaN         0
#
#                                                   genres  \
# 1660   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 6034   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 21046                     [{'id': 35, 'name': 'Comedy'}]
# 16296  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 30849  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage     id    imdb_id original_language  \
# 1660                                NaN    586  tt0120885                en
# 6034                                NaN   2984  tt0061523                en
# 21046  http://www.somebodythemovie.com/  97609  tt2014346                en
# ...

# %%
# Create Wikipedia dataframe

wiki_movies_df = pd.DataFrame(wiki_movies_raw)  
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
# Covert wikipedia dataframe columns into a list 
sorted(wiki_movies_df.columns.to_list())
# Out:
# ['Actor control',
#  'Adaptation by',
#  'Alias',
#  'Alma mater',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Area',
#  'Area served',
#  'Artist(s)',
#  'Attraction type',
#  'Audio format',
#  'Author',
#  'Based on',
#  'Biographical data',
#  'Bopomofo',
#  'Born',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Characters',
#  'Children',
#  'Chinese',
#  'Cinematography',
#  'Closing date',
#  'Color process',
#  'Comics',
#  'Composer(s)',
#  'Coordinates',
#  'Country',
#  'Country of origin',
#  'Cover artist',
#  'Created by',
#  'Date premiered',
#  'Designer(s)',
#  'Developed by',
#  'Developer(s)',
#  'Dewey Decimal',
#  'Died',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Divisions',
#  'Duration',
#  'Edited by',
#  'Editor(s)',
#  'Ending theme',
#  'Engine',
#  'Engine(s)',
#  'Executive producer(s)',
#  'Family',
#  'Fate',
#  'Film(s)',
#  'Followed by',
#  'Format(s)',
#  'Formerly',
#  'Founded',
# ...

# %%
#Remove madarin key
wiki_movies_df[wiki_movies_df['Mandarin'].notnull()]['url']
# Out:
# 887     https://en.wikipedia.org/wiki/The_Wedding_Banquet
# 1598    https://en.wikipedia.org/wiki/East_Palace,_Wes...
# 6674               https://en.wikipedia.org/wiki/Ip_Man_3
# 6834    https://en.wikipedia.org/wiki/The_Great_Wall_(...
# Name: url, dtype: object

# %%
wiki_movies = [movie for movie in wiki_movies_raw
            if( 'Director' in movie or 'Directed by' in movie)
            and 'imdb_link' in movie
            and 'No. of episodes' not in movie]

# %%
wiki_df = pd.DataFrame(wiki_movies)
wiki_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %%
# Remove unnecesary data from wiki_movies
def clean_movie(movie):
    movie = dict(movie) #create a non-disctructive copy
    alt_titles = {}
    for key in [ 'Also known as', 'Arabic', 'Cantonese', 'Chinese', 'French', 'Hangul',' Hebrew', 'Hepburn', 'Japanese', 'Literally',  'Mandarin', 'McCune–Reischauer', 'Original title', 'Polish',  'Revised Romanization', 'Romanized', 'Russian', 'Simplified', 'Traditional', 'Yiddish']:
        if key in movie:
            alt_titles[key] =  movie[key]
            movie.pop(key)
        if len(alt_titles) > 0:
            movie['alt_titles'] = alt_titles
# Merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
# Use clean_movie fucntion Clean data 
#Use clean_movies to loop through wiki_movies DataFrame
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# Transform clean_movies into a DataFrame
wiki_movies_df =pd.DataFrame(clean_movies)

# List of new columns
sorted(wiki_movies_df.columns.to_list())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Hebrew',
#  'Label',
#  'Language',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
square = lambda x : x * x
square(5)
# Out:
# 25

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Hebrew',
#  'Label',
#  'Language',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
# Extract imdb ID from wiki_movies_df
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# ...

# %%
# Count mostly null columns
[[column, wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 199],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['alt_titles', 7013],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['Hebrew', 7032],
# ...

# %%
#List of columns with < 90% null values
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# ...

# %%
# investigate wiki_movies_df data types
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
# Drop nulls in 'Box office' column
box_office = wiki_movies_df['Box office'].dropna()
len(box_office)
# Out:
# 5485

# %%
# Find !string function
def is_not_a_string(x):
    return type(x) != str

box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# Lambda != str to clean box office data
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# join characters in box_office interpretted as lists
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
box_office[6994]
# Out:
# '$365.6 million [1]'

# %%
# Regex for cleaning box_office earnings
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
# Count values matching first form
box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3903

# %%
# Regex for cleaning box_office matches in form_one
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'
# Count values matching form_two
box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1559

# %%
# Compare values in form_one and form_two
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 110              $4.35-4.37 million
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3088      $32 [2] –33.1 million [1]
# 3631                            TBA
# 3859             $38.9–40.3 million
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4261             $20.7–23.9 million
# 4306                         $20-30
# 4561        $45.2k (only in Turkey)
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6145             $17.5–18.4 million
# 6234             $41.8–41.9 million
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# Name: Box office, dtype: object

# %%
# Replace str on box_office ranges
# Contains param for all 3 dash types see https://en.wikipedia.org/wiki/Dash

box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# Extract and convert box_office values
#box_office.str.extract(f'({form_one}|{form_two})')

# Turn extracted values into numeric value
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on',s, flags=re.IGNORECASE):
        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        # convert to float and multiply by a million
        value = float(s) * 10**6
        # return value
        return value
    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on',s, flags=re.IGNORECASE):  
        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        # convert to float and multiply by a billion
        value = float(s) * 10**9
        # return value
        return value
    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):
            # remove dollar sign and commas
        s = re.sub('\$|,','', s)
            # convert to float
        value = float(s)
            # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

# %%
# Apply parse_dollars to the first column in the DataFrame returned by str.extract
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074     5500000.0
# 7075           NaN
# Name: box_office, Length: 7033, dtype: float64

# %%
# Drop 'box_office' column from DataFrame
wiki_movies_df.drop('Box office', axis=1, inplace=True)
wiki_movies_df.dtypes
# Out:
# url                       object
# year                       int64
# imdb_link                 object
# title                     object
# Based on                  object
# Starring                  object
# Cinematography            object
# Release date              object
# Running time              object
# Country                   object
# Language                  object
# Budget                    object
# Director                  object
# Distributor               object
# Editor(s)                 object
# Composer(s)               object
# Producer(s)               object
# Production company(s)     object
# Writer(s)                 object
# imdb_id                   object
# box_office               float64
# dtype: object

# %%
# Drop nulls in Budget column
budget = wiki_movies_df['Budget'].dropna()

# %%
len(budget)
# Out:
# 4738

# %%
# Convert lists in 'Budget' to strings
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# %%
budget
# Out:
# 0        $20 million
# 1         $6 million
# 2        $35 million
# 3        $12 million
# 4        $25 million
#             ...
# 7070    €4.3 million
# 7071     $42 million
# 7072     $60 million
# 7073     $20 million
# 7074      $9 million
# Name: Budget, Length: 4738, dtype: object

# %%
# Remove any values with $ or hyphens
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
budget
# Out:
# 0        $20 million
# 1         $6 million
# 2        $35 million
# 3        $12 million
# 4        $25 million
#             ...
# 7070    €4.3 million
# 7071     $42 million
# 7072     $60 million
# 7073     $20 million
# 7074      $9 million
# Name: Budget, Length: 4738, dtype: object

# %%
#Compare values in form_one and form_two
matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
budget[~matches_form_one & ~matches_form_two]



# Apply parse_dollars to the first column in the DataFrame returned by str.extract
#wiki_movies_df['Budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
#wiki_movies_df['Budget']
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# ...

# %%
#Remove the citation references
budget = budget.str.replace(r'\[\d+\]\s*', '')
budget[~matches_form_one & ~matches_form_two]
# Out:
# /Users/traverslaville/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973                     $34 million
# 1126                   $120 million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360                   $150 million
# 3418                        $218.32
# 3802                   £4.2 million
# ...

# %%
# Apply parse_dollars to the first column in the DataFrame returned by str.extract
wiki_movies_df['wiki_budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
# Drop the Budget column from wiki_movies_df
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
# Drop the budget column from wiki_movies_df
wiki_movies_df.drop('budget', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/35/ywx36bhn01b5j1yh3v59z83r0000gn/T/ipykernel_4380/880145498.py in <module>
#       1 # Drop the budget column from wiki_movies_df
# ----> 2 wiki_movies_df.drop('budget', axis=1, inplace=True)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Based on',
#  'Cinematography',
#  'Composer(s)',
#  'Country',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Language',
#  'Producer(s)',
#  'Production company(s)',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Writer(s)',
#  'box_office',
#  'imdb_id',
#  'imdb_link',
#  'title',
#  'url',
#  'wiki_budget',
#  'year']

# %%
# Variable to hold non-null values in Release date column
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
release_date

# %%
# Forms to parse Release date data
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[0123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# %%
# Extract dates from Release date
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)

# %%
# Parse extracted dates
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
wiki_movies_df['release_date']

# %%
# Parse Running Time
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
running_time

# %%
# Count expected Running Time format
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()

# %%
# Inspect remaining running Time formats
#running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False) != True]
#running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False).sum()
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]

# %%
# Extract values from Running Time
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')

# %%
running_time_extract

# %%
# Convert NaN to 0
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %%
running_time_extract

# %%
# Convert captured hour and minute groups if capture group is 0
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)
wiki_movies_df['running_time']

# %%
# Drop Running Time from the dataset
wiki_movies_df.drop('Running time', axis=1, inplace=True)

# %%
wiki_movies_df

# %%
# Initial look at kaggle metadata
kaggle_metadata.dtypes

# %%
# Investigation of Boolean values in adult
kaggle_metadata['adult'].value_counts()

# %%
# Remove bad data from adult column
kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]

# %%
# Keep movies where adult == False. Then drop adult column
kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')
kaggle_metadata

# %%
# Investigation of video column values
kaggle_metadata['video'].value_counts()

# %%
# Create Boolean video column
kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'

# %%
kaggle_metadata.dtypes

# %%
# Convert numeric columns to int
kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')

# %%
# Convert release_date to datetime
kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

# %%
# Reasonability Checks on ratings data
ratings.info(null_counts=True)

# %%
# Covert unix epoch
pd.to_datetime(ratings['timestamp'], unit='s')

# %%
# Assign timestamp values to timestamp column
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')

# %%
ratings['timestamp']

# %%
# Histogram of ratings
pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()

# %%
# Print list of metadata columns
movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])

# %%
movies_df.dtypes
# Out:
# url                       object
# year                       int64
# imdb_link                 object
# title_wiki                object
# Based on                  object
# Starring                  object
# Cinematography            object
# Release date              object
# Running time              object
# Country                   object
# Language                  object
# Director                  object
# Distributor               object
# Editor(s)                 object
# Composer(s)               object
# Producer(s)               object
# Production company(s)     object
# Writer(s)                 object
# imdb_id                   object
# box_office               float64
# wiki_budget              float64
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# original_language         object
# ...

# %% [markdown]
# # Competing data:
# |Wiki |Movielens  | Resolution|
# |-----|-----------|-----------|
# |title_wiki  | title_kaggle | Drop Wikipedia|
# |running_time   |runtime    |   |
# |budget_wiki    |budget_kaggle  |   |
# |box_office |revenue    |   |
# |release_date_wiki  |release_date_kaggle    |   |
# |Language   |original_language  |   |
# |Production company(s)  |production_companies   |   |

# %%
# Investigation of _wiki and _kaggle 'title'
movies_df[['title_wiki','title_kaggle']]
# Out:
#                            title_wiki                     title_kaggle
# 0     The Adventures of Ford Fairlane  The Adventures of Ford Fairlane
# 1                After Dark, My Sweet             After Dark, My Sweet
# 2                         Air America                      Air America
# 3                               Alice                            Alice
# 4                     Almost an Angel                  Almost an Angel
# ...                               ...                              ...
# 6047                A Fantastic Woman                A Fantastic Woman
# 6048                       Permission                       Permission
# 6049                         Loveless                         Loveless
# 6050                           Gemini                           Gemini
# 6051  How to Talk to Girls at Parties  How to Talk to Girls at Parties
#
# [6052 rows x 2 columns]

# %%
# Find rows in _wiki and _kaggle 'title' that do not match
movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki','title_kaggle']]
# Out:
#                                            title_wiki  \
# 27                                          China Cry
# 36               Daddy's Dyin' ...Who's Got the Will?
# 38                          The Dark Side of the Moon
# 42                                      Delta Force 2
# 48      DuckTales the Movie:Treasure of the Lost Lamp
# ...                                               ...
# 5956                                            Chips
# 5971                                            Spark
# 5994  Pirates of the Caribbean:Dead Men Tell No Tales
# 6023       Valerian and the Cityof a Thousand Planets
# 6028            An Inconvenient Sequel:Truth to Power
#
#                                           title_kaggle
# 27                             China Cry: A True Story
# 36                Daddy's Dyin'... Who's Got the Will?
# 38                           The Dark Side of The Moon
# 42             Delta Force 2: The Colombian Connection
# ...

# %%
# Show any rows where title_kaggle is empty
movies_df[(movies_df['title_kaggle'] == '') | (movies_df['title_kaggle'].isnull())]
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Release date, Running time, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, wiki_budget, adult, belongs_to_collection, budget, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 44 columns]

# %%
# Create a scatter plot to exaamine running_time vs runtime
movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'running_time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Create a scatter plot to compare budget_wiki and budget_kaggle
movies_df.fillna(0).plot(x='wiki_budget',y='budget', kind='scatter')
# Out:
# <AxesSubplot:xlabel='wiki_budget', ylabel='budget'>

# %%
sorted(movies_df.columns.tolist())

# %%
sorted()
